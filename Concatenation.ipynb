# %%
import pandas as pd

# %%
# for hand, change the 'Gastrocnemius - leg' in the file path to 'Extensor Digitorum - hand' and run the same script

# for chest, change the 'Gastrocnemius - leg\\accel+gyro.csv' in the file path to 'Pectoralis – chest\\accel+elec.csv' and run the same script

# %%
df1 = pd.read_csv('Data\\Intermediate Data\\S1\\Gastrocnemius - leg\\accel+gyro.csv')
df2 = pd.read_csv('Data\\Intermediate Data\\S2\\Gastrocnemius - leg\\accel+gyro.csv')
df3 = pd.read_csv('Data\\Intermediate Data\\S3\\Gastrocnemius - leg\\accel+gyro.csv')
df4 = pd.read_csv('Data\\Intermediate Data\\S4\\Gastrocnemius - leg\\accel+gyro.csv')
df5 = pd.read_csv('Data\\Intermediate Data\\S5\\Gastrocnemius - leg\\accel+gyro.csv')
df6 = pd.read_csv('Data\\Intermediate Data\\S6\\Gastrocnemius - leg\\accel+gyro.csv')
df7 = pd.read_csv('Data\\Intermediate Data\\S7\\Gastrocnemius - leg\\accel+gyro.csv')

# %%
df1['Subject ID'] = 1
df2['Subject ID'] = 2
df3['Subject ID'] = 3
df4['Subject ID'] = 4
df5['Subject ID'] = 5
df6['Subject ID'] = 6
df7['Subject ID'] = 7

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7], ignore_index = True)

# %%
df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1601749360010511    -0.991775     0.026184     0.158389
# 1               1601749360026503    -0.991531     0.038758     0.154726
# 2               1601749360042496    -0.986404     0.041810     0.169863
# 3               1601749360058488    -0.987869     0.036439     0.175357
# 4               1601749360074481    -0.995438     0.026673     0.185733
# ...                          ...          ...          ...          ...
# 142068          1604172861931284     0.989456     0.051331     0.077821
# 142069          1604172861947278     0.989700     0.040101     0.082704
# 142070          1604172861963271     0.994583     0.033509     0.090150
# 142071          1604172861979278     0.994461     0.030335     0.095155
# 142072          1604172861995272     0.989822     0.031556     0.093202
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s) Activity_Label  Subject ID
# ...

# %%
df.to_csv('Data\\Intermediate Data\\leg_concatenated.csv', sep=',',  index = False)
