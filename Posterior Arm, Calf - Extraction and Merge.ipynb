# %%
from datetime import datetime
import time
import pandas as pd
import numpy as np

# %%
# for other subjects, change the 'S6' in the file path to appropriate subject folder and run the same script

# for merging hand sensors, change the 'Gastrocnemius - leg' in the file path to 'Extensor Digitorum - hand' and run the same script

# %%
accel = pd.read_csv('Data\\Raw Data\\S6\\Gastrocnemius - leg\\accel.csv')
accel
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)
# 0                  1.604169e+15     0.961746     0.127749     0.235538
# 1                  1.604169e+15     0.962356     0.118837     0.253605
# 2                  1.604169e+15     0.952590     0.099062     0.264591
# 3                  1.604169e+15     0.947341     0.095399     0.255314
# 4                  1.604169e+15     0.939651     0.121279     0.273259
# ...                         ...          ...          ...          ...
# 17459              1.604171e+15     0.948440     0.125673     0.273503
# 17460              1.604171e+15     0.948806     0.099428     0.299748
# 17461              1.604171e+15     0.942458     0.112123     0.352605
# 17462              1.604171e+15     0.938674     0.118715     0.385199
# 17463              1.604171e+15     0.922683     0.105653     0.415961
#
# [17464 rows x 4 columns]

# %%
gyro = pd.read_csv('Data\\Raw Data\\S6\\Gastrocnemius - leg\\gyro.csv')
gyro
# Out:
#        Timestamp (microseconds)  Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)
# 0                  1.604169e+15     -2.227817      3.875792     -1.922637
# 1                  1.604169e+15     -4.180972      3.814755     -1.800565
# 2                  1.604169e+15     -3.692683      3.265431     -1.617456
# 3                  1.604169e+15      1.007095      2.716106     -1.983673
# 4                  1.604169e+15      3.997864      2.349889     -1.922637
# ...                         ...           ...           ...           ...
# 17461              1.604171e+15     -9.063859     15.106432     -8.575570
# 17462              1.604171e+15    -11.078050     14.923323     -9.308003
# 17463              1.604171e+15    -10.833906     14.801251    -10.101472
# 17464              1.604171e+15    -10.162509     13.824674    -11.322194
# 17465              1.604171e+15     -9.979400     12.603952    -12.176699
#
# [17466 rows x 4 columns]

# %% [markdown]
# # Merging data

# %%
df = accel.join(gyro.set_index('Timestamp (microseconds)'), on='Timestamp (microseconds)', how='inner')

# %%
df
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0                  1.604169e+15     0.961746     0.127749     0.235538
# 1                  1.604169e+15     0.962356     0.118837     0.253605
# 2                  1.604169e+15     0.952590     0.099062     0.264591
# 3                  1.604169e+15     0.947341     0.095399     0.255314
# 4                  1.604169e+15     0.939651     0.121279     0.273259
# ...                         ...          ...          ...          ...
# 17459              1.604171e+15     0.948440     0.125673     0.273503
# 17460              1.604171e+15     0.948806     0.099428     0.299748
# 17461              1.604171e+15     0.942458     0.112123     0.352605
# 17462              1.604171e+15     0.938674     0.118715     0.385199
# 17463              1.604171e+15     0.922683     0.105653     0.415961
#
#        Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)
# 0         -2.227817      3.875792     -1.922637
# ...

# %% [markdown]
# # Data filtering and adding labels

# %%
print(df['Timestamp (microseconds)'][0])
pd.Timestamp(df['Timestamp (microseconds)'][0], unit='us')
# Out:
# 1604169310006280.0
# Timestamp('2020-10-31 18:35:10.006280')

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2020, month = 10, day = 31, hour = 18, minute = 35, second = 10)
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2020, month = 10, day = 31, hour = 18, minute = 36, second = 39)
end_ts = int(end.timestamp() * 1e6)

stairs = df.loc[(df['Timestamp (microseconds)'] >= start_ts) & (df['Timestamp (microseconds)'] <= end_ts)]

stairs['Activity_Label'] = 'stairs'
stairs
# Out:
# C:\Users\mahaj\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0                 1.604169e+15     0.961746     0.127749     0.235538
# 1                 1.604169e+15     0.962356     0.118837     0.253605
# 2                 1.604169e+15     0.952590     0.099062     0.264591
# 3                 1.604169e+15     0.947341     0.095399     0.255314
# 4                 1.604169e+15     0.939651     0.121279     0.273259
# ...                        ...          ...          ...          ...
# ...

# %%
start = pd.Timestamp(year = 2020, month = 10, day = 31, hour = 18, minute = 44, second = 30)
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2020, month = 10, day = 31, hour = 18, minute = 45, second = 56)
end_ts = int(end.timestamp() * 1e6)

jog = df.loc[(df['Timestamp (microseconds)'] >= start_ts) & (df['Timestamp (microseconds)'] <= end_ts)]

jog['Activity_Label'] = 'jog'
jog
# Out:
# C:\Users\mahaj\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 5565               1.604170e+15     0.946975     0.176822     0.244694
# 5566               1.604170e+15     0.942702     0.194400     0.260319
# 5567               1.604170e+15     0.942702     0.196597     0.258854
# 5568               1.604170e+15     0.950881     0.187564     0.264958
# 5569               1.604170e+15     0.944533     0.231022     0.251408
# ...                         ...          ...          ...          ...
# 10937              1.604170e+15     1.250202     0.623484     0.044373
# ...

# %%
start = pd.Timestamp(year = 2020, month = 10, day = 31, hour = 18, minute = 50, second = 45)
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2020, month = 10, day = 31, hour = 18, minute = 50, second = 55)
end_ts = int(end.timestamp() * 1e6)

skip = df.loc[(df['Timestamp (microseconds)'] >= start_ts) & (df['Timestamp (microseconds)'] <= end_ts)]
skip['Activity_Label'] = 'skipping'
skip
# Out:
# C:\Users\mahaj\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 10942              1.604170e+15     0.899245     0.269474     0.380926
# 10943              1.604170e+15     0.849683     0.193912     0.253849
# 10944              1.604170e+15     0.913649     0.141665     0.211734
# 10945              1.604170e+15     1.005692     0.211368     0.214908
# 10946              1.604170e+15     0.997635     0.287785     0.218082
# ...                         ...          ...          ...          ...
# 11561              1.604170e+15    -0.825879     2.300633    -1.420127
# ...

# %%
start = pd.Timestamp(year = 2020, month = 10, day = 31, hour = 18, minute = 57, second = 30)
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2020, month = 10, day = 31, hour = 18, minute = 58, second = 11)
end_ts = int(end.timestamp() * 1e6)

kb = df.loc[(df['Timestamp (microseconds)'] >= start_ts) & (df['Timestamp (microseconds)'] <= end_ts)]
kb['Activity_Label'] = 'kettlebell'
kb
# Out:
# C:\Users\mahaj\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 11566              1.604171e+15     1.002152     0.060731     0.100038
# 11567              1.604171e+15     0.995926     0.073548     0.110414
# 11568              1.604171e+15     0.995438     0.097719     0.117372
# 11569              1.604171e+15     0.993973     0.099550     0.119570
# 11570              1.604171e+15     0.993851     0.075257     0.098573
# ...                         ...          ...          ...          ...
# 14125              1.604171e+15     0.954665     0.072572     0.196109
# ...

# %%
start = pd.Timestamp(year = 2020, month = 10, day = 31, hour = 19, minute = 1, second = 0)
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2020, month = 10, day = 31, hour = 19, minute = 2, second = 11)
end_ts = int(end.timestamp() * 1e6)

bb = df.loc[(df['Timestamp (microseconds)'] >= start_ts) & (df['Timestamp (microseconds)'] <= end_ts)]
bb['Activity_Label'] = 'basket ball'
bb
# Out:
# C:\Users\mahaj\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 14130              1.604171e+15     0.933913     0.085878     0.256535
# 14131              1.604171e+15     0.950393     0.066712     0.237980
# 14132              1.604171e+15     0.962844     0.093080     0.277531
# 14133              1.604171e+15     0.962966     0.143374     0.300481
# 14134              1.604171e+15     0.949538     0.149844     0.308171
# ...                         ...          ...          ...          ...
# 17459              1.604171e+15     0.948440     0.125673     0.273503
# ...

# %%
merged_df = pd.concat([stairs, jog, skip, kb, bb], ignore_index=True)

# %%
merged_df
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0                  1.604169e+15     0.961746     0.127749     0.235538
# 1                  1.604169e+15     0.962356     0.118837     0.253605
# 2                  1.604169e+15     0.952590     0.099062     0.264591
# 3                  1.604169e+15     0.947341     0.095399     0.255314
# 4                  1.604169e+15     0.939651     0.121279     0.273259
# ...                         ...          ...          ...          ...
# 17459              1.604171e+15     0.948440     0.125673     0.273503
# 17460              1.604171e+15     0.948806     0.099428     0.299748
# 17461              1.604171e+15     0.942458     0.112123     0.352605
# 17462              1.604171e+15     0.938674     0.118715     0.385199
# 17463              1.604171e+15     0.922683     0.105653     0.415961
#
#        Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s) Activity_Label
# ...

# %%
merged_df.to_csv('Data\\Intermediate Data\\S6\\Gastrocnemius - leg\\accel+gyro.csv', index = False)
